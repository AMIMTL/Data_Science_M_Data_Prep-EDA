# %% [markdown]
# # Assignments: Visualizing Data

# %% [markdown]
# ## Read in the data

# %%
import pandas as pd

songs = pd.read_csv('../Data/spotify_songs.csv')
songs.head()
# Out:
#                            name       artists  energy  key  mode  valence  \
# 0                    God's Plan         Drake   0.449    7     1    0.357
# 1                          SAD!  XXXTENTACION   0.613    8     1    0.473
# 2    rockstar (feat. 21 Savage)   Post Malone   0.535    5     0    0.140
# 3  Psycho (feat. Ty Dolla $ign)   Post Malone   0.559    8     1    0.439
# 4                In My Feelings         Drake   0.626    1     1    0.350
#
#      tempo  duration_ms
# 0   77.169       198973
# 1   75.023       166606
# 2  159.847       218147
# 3  140.124       221440
# 4   91.030       217925

# %%
songs.shape
# Out:
# (100, 8)

# %%
songs.artists.head(9)
# Out:
# 0            Drake
# 1     XXXTENTACION
# 2      Post Malone
# 3      Post Malone
# 4            Drake
# 5      Post Malone
# 6          Cardi B
# 7    Calvin Harris
# 8         Dua Lipa
# Name: artists, dtype: object

# %%
songs.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         100 non-null    object
#  1   artists      100 non-null    object
#  2   energy       100 non-null    float64
#  3   key          100 non-null    int64
#  4   mode         100 non-null    int64
#  5   valence      100 non-null    float64
#  6   tempo        100 non-null    float64
#  7   duration_ms  100 non-null    int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 18.6 KB

# %%
songs[songs.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [name, artists, energy, key, mode, valence, tempo, duration_ms]
# Index: []

# %%
songs[songs.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [name, artists, energy, key, mode, valence, tempo, duration_ms]
# Index: []

# %% [markdown]
# ## Distributions

# %% [markdown]
# Hi,
#
# Our music analysis team has labeled 100 songs with their musical attributes, such as its danceability and energy. Can you tell us more about the distributions of the musical attributes? I’m guessing that since most of the musical attributes are numeric, they should be normally distributed, but let me know if you see otherwise.
#
# Thanks!\
# Sarah

# %% [markdown]
# ### Interpret the histograms
#
# [Musical attribute definitions](https://developer.spotify.com/documentation/web-api/reference/get-audio-features)
#
# * Fields with normal distributions:
# * Fields with other distributions:
# * Skewed fields:
# * Outliers:
# * Other observations:
# * Do your interpretations make sense?

# %%
# Import the seaborn library
import seaborn as sns
sns.set_style('darkgrid')

# %%
# Create a pair plot
sns.pairplot(songs);
# Out:
# C:\Users\ahmad\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
songs.columns
# Out:
# Index(['name', 'artists', 'energy', 'key', 'mode', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
songs['energy'].round(1).value_counts().sort_index()
# Out:
# energy
# 0.3     4
# 0.4     8
# 0.5    11
# 0.6    19
# 0.7    26
# 0.8    25
# 0.9     7
# Name: count, dtype: int64

# %%
songs.loc[songs['energy'].round(1) == 0.6 , ['name','key']]
# Out:
#                                   name  key
# 1                                 SAD!    8
# 3         Psycho (feat. Ty Dolla $ign)    8
# 4                       In My Feelings    1
# 5                           Better Now   10
# 11                        Lucid Dreams    6
# 15            All The Stars (with SZA)    8
# 19            Look Alive (feat. Drake)   10
# 26            Love Lies (with Normani)    6
# 30                Taste (feat. Offset)    0
# 31            Solo (feat. Demi Lovato)   11
# 49                    Call Out My Name    1
# 53   Freaky Friday (feat. Chris Brown)    8
# 67                              Flames    5
# 68                      What Lovers Do    5
# 73                     Walk It Talk It    2
# 82                             HUMBLE.    1
# 94  Everybody Dies In Their Nightmares    7
# 95                   Rewrite The Stars   10
# 99                          Be Alright   11

# %%
songs['key'].value_counts()
# Out:
# key
# 1     15
# 8     11
# 5     10
# 9     10
# 0     10
# 11    10
# 2      7
# 6      7
# 7      6
# 10     5
# 4      5
# 3      4
# Name: count, dtype: int64

# %%
songs['key'].value_counts().sort_index()
# Out:
# key
# 0     10
# 1     15
# 2      7
# 3      4
# 4      5
# 5     10
# 6      7
# 7      6
# 8     11
# 9     10
# 10     5
# 11    10
# Name: count, dtype: int64

# %%
songs.columns
# Out:
# Index(['name', 'artists', 'energy', 'key', 'mode', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
songs.loc[songs['key'] == 0 , :]
# Out:
#                                                  name          artists  \
# 13                     Girls Like You (feat. Cardi B)         Maroon 5
# 20  These Days (feat. Jess Glynne, Macklemore & Da...       Rudimental
# 28                                     Jocelyn Flores     XXXTENTACION
# 30                               Taste (feat. Offset)             Tyga
# 34                                    ?chame La Culpa       Luis Fonsi
# 36                                  Never Be the Same   Camila Cabello
# 43                                            Thunder  Imagine Dragons
# 44                                           Me Niego             Reik
# 62                     Fuck Love (feat. Trippie Redd)     XXXTENTACION
# 97                                         No Brainer        DJ Khaled
#
#     energy  key  mode  valence    tempo  duration_ms
# 13   0.541    0     1    0.448  124.959       235545
# 20   0.809    0     1    0.550   92.213       210773
# 28   0.391    0     0    0.437  134.021       119133
# 30   0.559    0     1    0.342   97.994       232959
# 34   0.889    0     1    0.649   96.024       173720
# 36   0.713    0     1    0.243  129.923       226973
# 43   0.822    0     1    0.288  167.997       187147
# 44   0.779    0     0    0.768   94.023       221653
# 62   0.533    0     0    0.329  131.036       146520
# 97   0.760    0     1    0.639  135.702       260000

# %%
sns.histplot(songs['key']);

# %%
songs.columns
# Out:
# Index(['name', 'artists', 'energy', 'key', 'mode', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
    sns.histplot(songs['energy']);

# %%
songs['duration_ms'].hist();

# %%
songs.columns
# Out:
# Index(['name', 'artists', 'energy', 'key', 'mode', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
songs['tempo'].round(1).value_counts().sort_index()
# Out:
# tempo
# 64.9     1
# 75.0     1
# 77.2     1
# 79.0     1
# 80.0     1
#         ..
# 180.0    2
# 180.1    1
# 182.0    1
# 191.7    1
# 198.1    1
# Name: count, Length: 75, dtype: int64

# %%
sns.histplot(songs['tempo']);

# %%
songs['valence'].round(1).value_counts().sort_index(ascending=1)
# Out:
# valence
# 0.1     5
# 0.2     9
# 0.3    12
# 0.4    23
# 0.5    11
# 0.6    17
# 0.7    11
# 0.8    10
# 0.9     2
# Name: count, dtype: int64

# %%
songs['valence'].round(1).sort_index(ascending=1)
# Out:
# 0     0.4
# 1     0.5
# 2     0.1
# 3     0.4
# 4     0.4
#      ...
# 95    0.3
# 96    0.3
# 97    0.6
# 98    0.1
# 99    0.4
# Name: valence, Length: 100, dtype: float64

# %%
sns.histplot(songs['valence']
            );

# %%
songs.head()
# Out:
#                            name       artists  energy  key  mode  valence  \
# 0                    God's Plan         Drake   0.449    7     1    0.357
# 1                          SAD!  XXXTENTACION   0.613    8     1    0.473
# 2    rockstar (feat. 21 Savage)   Post Malone   0.535    5     0    0.140
# 3  Psycho (feat. Ty Dolla $ign)   Post Malone   0.559    8     1    0.439
# 4                In My Feelings         Drake   0.626    1     1    0.350
#
#      tempo  duration_ms
# 0   77.169       198973
# 1   75.023       166606
# 2  159.847       218147
# 3  140.124       221440
# 4   91.030       217925

# %%
songs['name'].head()
# Out:
# 0                      God's Plan
# 1                            SAD!
# 2      rockstar (feat. 21 Savage)
# 3    Psycho (feat. Ty Dolla $ign)
# 4                  In My Feelings
# Name: name, dtype: object

# %%
songs['name'] = songs['name'].str.capitalize()
songs[songs['name'].str.startswith("?") ]
songs.loc[34,'name'] = 'chame la culpa'

# %%
songs[songs['name'].str.startswith("?") ]
# Out:
# Empty DataFrame
# Columns: [name, artists, energy, key, mode, valence, tempo, duration_ms]
# Index: []

# %%
# Out:
# <style type="text/css">
# #T_530ef_row0_col0, #T_530ef_row1_col1, #T_530ef_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_530ef_row0_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_530ef_row0_col2, #T_530ef_row1_col2, #T_530ef_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_530ef_row1_col0 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_530ef_row2_col0 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_530ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_530ef_level0_col0" class="col_heading level0 col0" >energy</th>
#       <th id="T_530ef_level0_col1" class="col_heading level0 col1" >valence</th>
#       <th id="T_530ef_level0_col2" class="col_heading level0 col2" >tempo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_530ef_level0_row0" class="row_heading level0 row0" >energy</th>
#       <td id="T_530ef_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_530ef_row0_col1" class="data row0 col1" >0.380000</td>
#       <td id="T_530ef_row0_col2" class="data row0 col2" >0.060000</td>
#     </tr>
#     <tr>
#       <th id="T_530ef_level0_row1" class="row_heading level0 row1" >valence</th>
#       <td id="T_530ef_row1_col0" class="data row1 col0" >0.380000</td>
#       <td id="T_530ef_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_530ef_row1_col2" class="data row1 col2" >-0.150000</td>
#     </tr>
#     <tr>
#       <th id="T_530ef_level0_row2" class="row_heading level0 row2" >tempo</th>
#       <td id="T_530ef_row2_col0" class="data row2 col0" >0.060000</td>
#       <td id="T_530ef_row2_col1" class="data row2 col1" >-0.150000</td>
#       <td id="T_530ef_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Correlations

# %% [markdown]
# Hi again,
#
# Thanks for looking into those distributions earlier. Can you also tell us more about the correlations of the musical attributes?
# Can you tell us about any relationships you can find in the data between the attributes, like if some are positively or negatively correlated?
#
# Thanks!\
# Sarah

# %% [markdown]
# ### Interpret the scatter plots
#
# [Musical attribute definitions](https://developer.spotify.com/documentation/web-api/reference/get-audio-features)
#
# * Highly correlated: None
# * Uncorrelated: key vs[energy,valence, tempo]
# * Positive correlation: energy vs valence
# * Negative correlation: key vs[energy,mode,valence]
# * Other observations:
# * Do your interpretations make sense?

# %%
songs.head()
# Out:
#                            name       artists  energy  key  mode  valence  \
# 0                    God's plan         Drake   0.449    7     1    0.357
# 1                          Sad!  XXXTENTACION   0.613    8     1    0.473
# 2    Rockstar (feat. 21 savage)   Post Malone   0.535    5     0    0.140
# 3  Psycho (feat. ty dolla $ign)   Post Malone   0.559    8     1    0.439
# 4                In my feelings         Drake   0.626    1     1    0.350
#
#      tempo  duration_ms
# 0   77.169       198973
# 1   75.023       166606
# 2  159.847       218147
# 3  140.124       221440
# 4   91.030       217925

# %%
sns.pairplot(songs);
# Out:
# C:\Users\ahmad\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
(songs.loc[:,['energy','key','mode','valence','tempo','duration_ms']].corr().
 round(2).
 style.
 background_gradient(cmap = "RdYlGn", axis =1))
# Out:
# <style type="text/css">
# #T_47873_row0_col0, #T_47873_row1_col1, #T_47873_row2_col2, #T_47873_row3_col3, #T_47873_row4_col4, #T_47873_row5_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_47873_row0_col1, #T_47873_row1_col0, #T_47873_row1_col2, #T_47873_row2_col3, #T_47873_row3_col2, #T_47873_row4_col3, #T_47873_row5_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_47873_row0_col2 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_47873_row0_col3 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_47873_row0_col4 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_47873_row0_col5 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_47873_row1_col3 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_47873_row1_col4, #T_47873_row4_col2, #T_47873_row5_col4 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_47873_row1_col5, #T_47873_row2_col4 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_47873_row2_col0 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_47873_row2_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_47873_row2_col5 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_47873_row3_col0 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_47873_row3_col1 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_47873_row3_col4 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_47873_row3_col5 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_47873_row4_col0 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_47873_row4_col1 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_47873_row4_col5 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_47873_row5_col0 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_47873_row5_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_47873_row5_col2 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_47873">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47873_level0_col0" class="col_heading level0 col0" >energy</th>
#       <th id="T_47873_level0_col1" class="col_heading level0 col1" >key</th>
#       <th id="T_47873_level0_col2" class="col_heading level0 col2" >mode</th>
#       <th id="T_47873_level0_col3" class="col_heading level0 col3" >valence</th>
#       <th id="T_47873_level0_col4" class="col_heading level0 col4" >tempo</th>
#       <th id="T_47873_level0_col5" class="col_heading level0 col5" >duration_ms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47873_level0_row0" class="row_heading level0 row0" >energy</th>
#       <td id="T_47873_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_47873_row0_col1" class="data row0 col1" >-0.140000</td>
#       <td id="T_47873_row0_col2" class="data row0 col2" >-0.120000</td>
#       <td id="T_47873_row0_col3" class="data row0 col3" >0.380000</td>
#       <td id="T_47873_row0_col4" class="data row0 col4" >0.060000</td>
#       <td id="T_47873_row0_col5" class="data row0 col5" >0.070000</td>
#     </tr>
#     <tr>
#       <th id="T_47873_level0_row1" class="row_heading level0 row1" >key</th>
#       <td id="T_47873_row1_col0" class="data row1 col0" >-0.140000</td>
#       <td id="T_47873_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_47873_row1_col2" class="data row1 col2" >-0.140000</td>
#       <td id="T_47873_row1_col3" class="data row1 col3" >-0.030000</td>
#       <td id="T_47873_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_47873_row1_col5" class="data row1 col5" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_47873_level0_row2" class="row_heading level0 row2" >mode</th>
#       <td id="T_47873_row2_col0" class="data row2 col0" >-0.120000</td>
#       <td id="T_47873_row2_col1" class="data row2 col1" >-0.140000</td>
#       <td id="T_47873_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_47873_row2_col3" class="data row2 col3" >-0.210000</td>
#       <td id="T_47873_row2_col4" class="data row2 col4" >-0.010000</td>
#       <td id="T_47873_row2_col5" class="data row2 col5" >0.060000</td>
#     </tr>
#     <tr>
#       <th id="T_47873_level0_row3" class="row_heading level0 row3" >valence</th>
#       <td id="T_47873_row3_col0" class="data row3 col0" >0.380000</td>
#       <td id="T_47873_row3_col1" class="data row3 col1" >-0.030000</td>
#       <td id="T_47873_row3_col2" class="data row3 col2" >-0.210000</td>
#       <td id="T_47873_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_47873_row3_col4" class="data row3 col4" >-0.150000</td>
#       <td id="T_47873_row3_col5" class="data row3 col5" >-0.130000</td>
#     </tr>
#     <tr>
#       <th id="T_47873_level0_row4" class="row_heading level0 row4" >tempo</th>
#       <td id="T_47873_row4_col0" class="data row4 col0" >0.060000</td>
#       <td id="T_47873_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_47873_row4_col2" class="data row4 col2" >-0.010000</td>
#       <td id="T_47873_row4_col3" class="data row4 col3" >-0.150000</td>
#       <td id="T_47873_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_47873_row4_col5" class="data row4 col5" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_47873_level0_row5" class="row_heading level0 row5" >duration_ms</th>
#       <td id="T_47873_row5_col0" class="data row5 col0" >0.070000</td>
#       <td id="T_47873_row5_col1" class="data row5 col1" >0.050000</td>
#       <td id="T_47873_row5_col2" class="data row5 col2" >0.060000</td>
#       <td id="T_47873_row5_col3" class="data row5 col3" >-0.130000</td>
#       <td id="T_47873_row5_col4" class="data row5 col4" >0.010000</td>
#       <td id="T_47873_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
energy vs valence
